# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 as c

# %%
image = c.imread("../data/images/scene00011.png")
image = c.cvtColor(image, c.COLOR_BGR2RGB)
hsv = c.cvtColor(image, c.COLOR_RGB2HSV)
hist = c.calcHist([image],[0], None, [256], [0,256])

# %%
plt.figure()
plt.subplot(211)
plt.plot(hist)

# %%
plt.imshow(image)

# %%
new_image = np.zeros(image.shape, image.dtype)
new_image = c.convertScaleAbs(image, alpha=0.2, beta=0)

# %%
plt.imshow(new_image)

# %%
ord('+')
# Out:
# 43

# %%
fliped = c.flip(image, 1)
fliped = c.flip(fliped, 1)
plt.imshow(fliped)
#plt.imshow(image)

# %%
# !True
# Out:
# /usr/bin/sh: 1: True: not found

# %%
not True
# Out:
# False

# %%
from randint import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-0c3efa08b7f7> in <module>
# ----> 1 from randint import random
#
# ModuleNotFoundError: No module named 'randint'

# %%
import random

# %%
random.randint(8,15)
# Out:
# 0.9

# %%
x = random.uniform(0.8,1.5)
round(x, 1)
# Out:
# 0.9

# %%
import os

# %%
list(os.dir())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c8430db428c1> in <module>
# ----> 1 list(os.dir())
#
# AttributeError: module 'os' has no attribute 'dir'

# %%
os.dir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-d86cfd44b672> in <module>
# ----> 1 os.dir
#
# AttributeError: module 'os' has no attribute 'dir'

# %%
os.dir()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1b798660c993> in <module>
# ----> 1 os.dir()
#
# AttributeError: module 'os' has no attribute 'dir'

# %%
ls
# Out:
# 'createmasks(DR_Ilias).ipynb'   testen.ipynb
#  createMasks-V-0.ipynb          training.ipynb
# 'lifepics(DR_ilias).ipynb'     'trainpics(DR_ilias).ipynb'

# %%
cd ..
# Out:
# /home/moamen/myGitRepos/AutonomesFahren/implementation

# %%
ls
# Out:
# ipynb/  py/  testImages/

# %%
cd testImages/
# Out:
# /home/moamen/myGitRepos/AutonomesFahren/implementation/testImages

# %%
LS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e3e55ccad076> in <module>
# ----> 1 LS
#
# NameError: name 'LS' is not defined

# %%
ls
# Out:
# image.json  image.png

# %%
file = open("image.json")

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='image.json' mode='r' encoding='UTF-8'>

# %%
jsonfile = json.load(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0e8d50ff7617> in <module>
# ----> 1 jsonfile = json.load(file)
#
# NameError: name 'json' is not defined

# %%
import json

# %%
jsonfile = json.

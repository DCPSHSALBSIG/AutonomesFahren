# %%
from skimage.draw import polygon
import PIL
import json
import base64
import os.path
from os.path import splitext
import cv2
import numpy as np
import imutils
import matplotlib.pyplot as plt
import re
from random import *

# %%
classes = {"Strasse" : 1, 
           "strasse" : 1,
          "Streifen" : 2,
           "streifen" : 2,
          "Auto" : 3, 
          "auto" : 3,
          "Schild" : 4,
           "schild" : 4,
         }

colors = {0 : (0,0,0), 
          1 : (0,0,255), 
          2 : (0,255,0),
          3 : (255,0,0), 
          4 : (0,255,255),         
         }

dim = (256, 256) 

path =  r'/home/inf/Bilder/Road'
dirjson = "jsons"
dirimages = "images"
dirmasks = "masks"
dirimagesaugmented = "images_augmented"
dirmasksaugmented = "masks_augmented"

dirjsonsvalid = "jsons_valid"
dirimagesvalid = "images_valid"
dirmasksvalid = "masks_valid"

dirjsonstest = "jsons_test"
dirimagestest = "images_test"
dirmaskstest = "masks_test"

fullpathjson = os.path.join(path, dirjson)
fullpathimages = os.path.join(path, dirimages)
fullpathmasks = os.path.join(path, dirmasks)

fullpathimagesaugmented = os.path.join(path, dirimagesaugmented)
fullpathmasksaugmented = os.path.join(path, dirmasksaugmented)

fullpathjsonsvalid = os.path.join(path, dirjsonsvalid)
fullpathimagesvalid = os.path.join(path, dirimagesvalid)
fullpathmasksvalid = os.path.join(path, dirmasksvalid)

fullpathjsonstest = os.path.join(path, dirjsonstest)
fullpathimagestest = os.path.join(path, dirimagestest)
fullpathmaskstest = os.path.join(path, dirmaskstest)

print(os.path.exists(fullpathjson))
print(os.path.exists(fullpathimages))
print(os.path.exists(fullpathmasks))
print(os.path.exists(fullpathmasksvalid))
# Out:
# True
# True
# True
# True

# %%
def makesquare2(img):
    
    assert(img.ndim == 2) 
    
    edge = min(img.shape[0],img.shape[1])
        
    img_sq = np.zeros((edge, edge), 'uint8')
    
    if(edge == img.shape[0]):
        img_sq[:,:] = img[:,int((img.shape[1] - edge)/2):int((img.shape[1] - edge)/2)+edge]
    else:
        img_sq[:,:,:] = img[int((img.shape[0] - edge)/2):int((img.shape[0] - edge)/2)+edge,:]

    assert(img_sq.shape[0] == edge and img_sq.shape[1] == edge)
    
    return img_sq

# %%
def makesquare3(img):
    
    assert(img.ndim == 3)
    
    edge = min(img.shape[0],img.shape[1])
        
    img_sq = np.zeros((edge, edge, 3), 'uint8')
    
    if(edge == img.shape[0]):
        img_sq[:,:,:] = img[:,int((img.shape[1] - edge)/2):int((img.shape[1] - edge)/2)+edge,:]
    else:
        img_sq[:,:,:] = img[int((img.shape[0] - edge)/2):int((img.shape[0] - edge)/2)+edge,:,:]

    assert(img_sq.shape[0] == edge and img_sq.shape[1] == edge)
    
    return img_sq

# %%
def testMasks(sourcejsonsdir, destimagesdir, destmasksdir):
    count = 0
    directory = sourcejsonsdir
    for filename in os.listdir(directory):
        if filename.endswith(".json"):
            print("{}:{}".format(count,os.path.join(directory, filename)))
            f = open(os.path.join(directory, filename))
            data = json.load(f)
            #print(data['imagePath'])
            img_arr = data['imageData']  
            imgdata = base64.b64decode(img_arr)

            img = cv2.imdecode(np.frombuffer(imgdata, dtype=np.uint8), flags=cv2.IMREAD_COLOR)

            #print(img.shape[0])
            #print(img.shape[1])
            
            assert (img.shape[0] > dim[0])
            assert (img.shape[1] > dim[1])
           
            img = makesquare3(img)

            #assert(img.shape[0] == img.shape[1])
          
            for shape in data['shapes']:
                if not (shape['label'] in classes):
                    f.close()
                    assert(0 > 1)
                
            count += 1
            
            f.close()

# %%
testMasks(fullpathjson, fullpathimages, fullpathmasks)
testMasks(fullpathjsonsvalid, fullpathimagesvalid, fullpathmasksvalid)
#testMasks(fullpathjsonstest, fullpathimagestest, fullpathmaskstest)
# Out:
# 0:/home/inf/Bilder/Road/jsons/image0144.json
# 1:/home/inf/Bilder/Road/jsons/image0072.json
# 2:/home/inf/Bilder/Road/jsons/image0079.json
# 3:/home/inf/Bilder/Road/jsons/image0124.json
# 4:/home/inf/Bilder/Road/jsons/image0135.json
# 5:/home/inf/Bilder/Road/jsons/image0208.json
# 6:/home/inf/Bilder/Road/jsons/image0140.json
# 7:/home/inf/Bilder/Road/jsons/image0138.json
# 8:/home/inf/Bilder/Road/jsons/image0039.json
# 9:/home/inf/Bilder/Road/jsons/image0154.json
# 10:/home/inf/Bilder/Road/jsons/image0026.json
# 11:/home/inf/Bilder/Road/jsons/image0141.json
# 12:/home/inf/Bilder/Road/jsons/image0220.json
# 13:/home/inf/Bilder/Road/jsons/image0018.json
# 14:/home/inf/Bilder/Road/jsons/image0041.json
# 15:/home/inf/Bilder/Road/jsons/image0175.json
# 16:/home/inf/Bilder/Road/jsons/image0216.json
# 17:/home/inf/Bilder/Road/jsons/image0177.json
# 18:/home/inf/Bilder/Road/jsons/image0096.json
# 19:/home/inf/Bilder/Road/jsons/image0225.json
# 20:/home/inf/Bilder/Road/jsons/image0103.json
# 21:/home/inf/Bilder/Road/jsons/image0028.json
# 22:/home/inf/Bilder/Road/jsons/image0157.json
# 23:/home/inf/Bilder/Road/jsons/image0046.json
# 24:/home/inf/Bilder/Road/jsons/image0169.json
# 25:/home/inf/Bilder/Road/jsons/image0098.json
# 26:/home/inf/Bilder/Road/jsons/image0061.json
# 27:/home/inf/Bilder/Road/jsons/image0195.json
# 28:/home/inf/Bilder/Road/jsons/image0172.json
# 29:/home/inf/Bilder/Road/jsons/image0129.json
# 30:/home/inf/Bilder/Road/jsons/image0145.json
# 31:/home/inf/Bilder/Road/jsons/image0036.json
# 32:/home/inf/Bilder/Road/jsons/image0125.json
# 33:/home/inf/Bilder/Road/jsons/image0095.json
# 34:/home/inf/Bilder/Road/jsons/image0229.json
# 35:/home/inf/Bilder/Road/jsons/image0063.json
# 36:/home/inf/Bilder/Road/jsons/image0207.json
# 37:/home/inf/Bilder/Road/jsons/image0230.json
# 38:/home/inf/Bilder/Road/jsons/image0209.json
# 39:/home/inf/Bilder/Road/jsons/image0123.json
# 40:/home/inf/Bilder/Road/jsons/image0119.json
# 41:/home/inf/Bilder/Road/jsons/image0021.json
# 42:/home/inf/Bilder/Road/jsons/image0127.json
# 206:/home/inf/Bilder/Road/jsons/image0163.json
# 207:/home/inf/Bilder/Road/jsons/image0202.json
# 0:/home/inf/Bilder/Road/jsons_valid/image0016.json
# 1:/home/inf/Bilder/Road/jsons_valid/image0002.json
# 2:/home/inf/Bilder/Road/jsons_valid/image0186.json
# 3:/home/inf/Bilder/Road/jsons_valid/image0038.json
# 4:/home/inf/Bilder/Road/jsons_valid/image0224.json
# 5:/home/inf/Bilder/Road/jsons_valid/image0107.json
# 6:/home/inf/Bilder/Road/jsons_valid/image0204.json
# 7:/home/inf/Bilder/Road/jsons_valid/image0132.json
# 8:/home/inf/Bilder/Road/jsons_valid/image0221.json
# 9:/home/inf/Bilder/Road/jsons_valid/image0206.json
# 10:/home/inf/Bilder/Road/jsons_valid/image0068.json
# 11:/home/inf/Bilder/Road/jsons_valid/image0059.json
# 12:/home/inf/Bilder/Road/jsons_valid/image0110.json
# 13:/home/inf/Bilder/Road/jsons_valid/image0134.json
# 14:/home/inf/Bilder/Road/jsons_valid/image0232.json
# 15:/home/inf/Bilder/Road/jsons_valid/image0083.json
# 16:/home/inf/Bilder/Road/jsons_valid/image0158.json
# 17:/home/inf/Bilder/Road/jsons_valid/image0092.json
# 18:/home/inf/Bilder/Road/jsons_valid/image0155.json
# 19:/home/inf/Bilder/Road/jsons_valid/image0187.json

# %%
def createMasks(sourcejsonsdir, destimagesdir, destmasksdir):

    assocf = open(os.path.join(path,"assoc_orig.txt"), "w")
    #assocfile = open("assoc_orig.txt", "w")
    #print(os.path.join(path,"assoc_orig.txt"))
    #print(os.path.exists(os.path.join(path,"assoc_orig.txt")))
    #print(f.writable())
    #f.write("")
    count = 0
    directory = sourcejsonsdir
    for filename in os.listdir(directory):
        if filename.endswith(".json"):
            print("{}:{}".format(count,os.path.join(directory, filename)))
            
            f = open(os.path.join(directory, filename))
            data = json.load(f)
            #print(data['imagePath'])
            img_arr = data['imageData']  
            imgdata = base64.b64decode(img_arr)

            img = cv2.imdecode(np.frombuffer(imgdata, dtype=np.uint8), flags=cv2.IMREAD_COLOR)
            
            assert (img.shape[0] > dim[0])
            assert (img.shape[1] > dim[1])
           
            finalmask = np.zeros((img.shape[0], img.shape[1]), 'uint8')
            #finalmask_strasse = np.zeros((img.shape[0], img.shape[1]), 'uint8')
        
            masks=[]
            masks_strassen=[]
            mask_strasse = np.zeros((img.shape[0], img.shape[1]), 'uint8')
            
            
            for shape in data['shapes']:
                assert(shape['label'] in classes)

                vertices = np.array([[point[1],point[0]] for point in shape['points']])
                vertices = vertices.astype(int)

                rr, cc = polygon(vertices[:,0], vertices[:,1], img.shape)
                mask_orig = np.zeros((img.shape[0], img.shape[1]), 'uint8')

                mask_orig[rr,cc] = classes[shape['label']]
                if classes[shape['label']] != classes['Strasse']:
                    masks.append(mask_orig)
                else:
                    masks_strassen.append(mask_orig)
                    
            for m in masks_strassen:
                mask_strasse += m
                    
            for m in masks:
                _,mthresh = cv2.threshold(m,1,255,cv2.THRESH_BINARY_INV)
                finalmask = cv2.bitwise_and(finalmask,finalmask,mask = mthresh)
                finalmask += m

            _,mthresh = cv2.threshold(finalmask,1,255,cv2.THRESH_BINARY_INV)
            mask_strasse = cv2.bitwise_and(mask_strasse,mask_strasse, mask = mthresh)
            finalmask += mask_strasse  
                
            img = makesquare3(img)
            finalmask = makesquare2(finalmask)

            img_resized = cv2.resize(img, dim, interpolation = cv2.INTER_NEAREST)
            finalmask_resized = cv2.resize(finalmask, dim, interpolation = cv2.INTER_NEAREST)
            
            filepure,extension = splitext(filename)
            
            cv2.imwrite(os.path.join(destimagesdir, "{}o.png".format(filepure)), img_resized)
            cv2.imwrite(os.path.join(destmasksdir, "{}o.png".format(filepure)), finalmask_resized)

            assocf.write("{:05d}o:{}\n".format(count,filename))
            assocf.flush()
            count += 1

        else:
            continue
    f.close()

# %%
def createMasksAugmented(ident, sourcejsonsdir, destimagesdir, destmasksdir):

    assocf = open(os.path.join(path,"assoc_{}_augmented.txt".format(ident)), "w")

    count = 0
    directory = sourcejsonsdir
    for filename in os.listdir(directory):
        if filename.endswith(".json"):
            print("{}:{}".format(count,os.path.join(directory, filename)))
            #print(os.path.join(directory, filename))

            f = open(os.path.join(directory, filename))
            data = json.load(f)
            #print(data['imagePath'])
            img_arr = data['imageData']  
            imgdata = base64.b64decode(img_arr)

            img = cv2.imdecode(np.frombuffer(imgdata, dtype=np.uint8), flags=cv2.IMREAD_COLOR)
            
            assert (img.shape[0] > dim[0])
            assert (img.shape[1] > dim[1])
            
            zoom = randint(75,90)/100.0
            angle = (2*random()-1)*3.0
            img_rotated = imutils.rotate_bound(img, angle)
            
            xf = int(img_rotated.shape[0]*zoom)
            yf = int(img_rotated.shape[1]*zoom)            
            
            img_zoomed = np.zeros((xf, yf, img_rotated.shape[2]), 'uint8')
            img_zoomed[:,:,:] = img_rotated[int((img_rotated.shape[0]-xf)/2):int((img_rotated.shape[0]-xf)/2)+xf,int((img_rotated.shape[1]-yf)/2):int((img_rotated.shape[1]-yf)/2)+yf,:] 
        

            finalmask = np.zeros((img_zoomed.shape[0], img_zoomed.shape[1]), 'uint8')
            mthresh = np.zeros((img_zoomed.shape[0], img_zoomed.shape[1]), 'uint8')
            masks=[]
            masks_strassen=[]
            mask_strasse = np.zeros((img_zoomed.shape[0], img_zoomed.shape[1]), 'uint8')

            for shape in data['shapes']:
                assert(shape['label'] in classes)

                vertices = np.array([[point[1],point[0]] for point in shape['points']])
                vertices = vertices.astype(int)

                rr, cc = polygon(vertices[:,0], vertices[:,1], img.shape)
                mask_orig = np.zeros((img.shape[0], img.shape[1]), 'uint8')
                mask_orig[rr,cc] = classes[shape['label']]
                
                mask_rotated = imutils.rotate_bound(mask_orig, angle)
                
                mask_zoomed = np.zeros((xf, yf), 'uint8')
                mask_zoomed[:,:] = mask_rotated[int((img_rotated.shape[0]-xf)/2):int((img_rotated.shape[0]-xf)/2)+xf,int((img_rotated.shape[1]-yf)/2):int((img_rotated.shape[1]-yf)/2)+yf] 
                
                if classes[shape['label']] != classes['Strasse']:
                    masks.append(mask_zoomed)
                else:
                    masks_strassen.append(mask_zoomed)

            for m in masks_strassen:
                mask_strasse += m
                    
            for m in masks:
                _,mthresh = cv2.threshold(m,1,255,cv2.THRESH_BINARY_INV)
                finalmask = cv2.bitwise_and(finalmask,finalmask,mask = mthresh)
                finalmask += m

            _,mthresh = cv2.threshold(finalmask,1,255,cv2.THRESH_BINARY_INV)
            mask_strasse = cv2.bitwise_and(mask_strasse,mask_strasse, mask = mthresh)
            finalmask += mask_strasse    
    
            # contrast-> alpha: 1.0 - 3.0; brightness -> beta: 0 - 100
            alpha = 0.8 + 0.4*random();
            beta = int(random()*15)
    
            img_adjusted = cv2.convertScaleAbs(img_zoomed, alpha=alpha, beta=beta)
        
        
            img_adjusted = makesquare3(img_adjusted)
            finalmask = makesquare2(finalmask)

            img_resized = cv2.resize(img_adjusted, dim, interpolation = cv2.INTER_NEAREST)
            finalmask_resized = cv2.resize(finalmask, dim, interpolation = cv2.INTER_NEAREST)
            
            filepure,extension = splitext(filename)
            
            cv2.imwrite(os.path.join(destimagesdir, "{}{}.png".format(filepure, ident)), img_resized)
            cv2.imwrite(os.path.join(destmasksdir, "{}{}.png".format(filepure, ident)), finalmask_resized) 

            assocf.write("{:05d}:{}\n".format(count, filename))
            assocf.flush()
            count += 1

        else:
            continue
    f.close()

# %%
createMasks(fullpathjson, fullpathimages, fullpathmasks)
createMasksAugmented("a1",fullpathjson, fullpathimages, fullpathmasks)
createMasksAugmented("a2",fullpathjson, fullpathimages, fullpathmasks)
createMasksAugmented("a3",fullpathjson, fullpathimages, fullpathmasks)
# Out:
# 0:/home/inf/Bilder/Road/jsons/image0144.json
# 1:/home/inf/Bilder/Road/jsons/image0072.json
# 2:/home/inf/Bilder/Road/jsons/image0079.json
# 3:/home/inf/Bilder/Road/jsons/image0124.json
# 4:/home/inf/Bilder/Road/jsons/image0135.json
# 5:/home/inf/Bilder/Road/jsons/image0208.json
# 6:/home/inf/Bilder/Road/jsons/image0140.json
# 7:/home/inf/Bilder/Road/jsons/image0138.json
# 8:/home/inf/Bilder/Road/jsons/image0039.json
# 9:/home/inf/Bilder/Road/jsons/image0154.json
# 10:/home/inf/Bilder/Road/jsons/image0026.json
# 11:/home/inf/Bilder/Road/jsons/image0141.json
# 12:/home/inf/Bilder/Road/jsons/image0220.json
# 13:/home/inf/Bilder/Road/jsons/image0018.json
# 14:/home/inf/Bilder/Road/jsons/image0041.json
# 15:/home/inf/Bilder/Road/jsons/image0175.json
# 16:/home/inf/Bilder/Road/jsons/image0216.json
# 17:/home/inf/Bilder/Road/jsons/image0177.json
# 18:/home/inf/Bilder/Road/jsons/image0096.json
# 19:/home/inf/Bilder/Road/jsons/image0225.json
# 20:/home/inf/Bilder/Road/jsons/image0103.json
# 21:/home/inf/Bilder/Road/jsons/image0028.json
# 22:/home/inf/Bilder/Road/jsons/image0157.json
# 23:/home/inf/Bilder/Road/jsons/image0046.json
# 24:/home/inf/Bilder/Road/jsons/image0169.json
# 25:/home/inf/Bilder/Road/jsons/image0098.json
# 199:/home/inf/Bilder/Road/jsons/image0074.json
# 200:/home/inf/Bilder/Road/jsons/image0146.json
# 201:/home/inf/Bilder/Road/jsons/image0075.json
# 202:/home/inf/Bilder/Road/jsons/image0060.json
# 203:/home/inf/Bilder/Road/jsons/image0190.json
# 204:/home/inf/Bilder/Road/jsons/image0064.json
# 205:/home/inf/Bilder/Road/jsons/image0053.json
# 206:/home/inf/Bilder/Road/jsons/image0163.json
# 207:/home/inf/Bilder/Road/jsons/image0202.json
# 0:/home/inf/Bilder/Road/jsons/image0144.json
# 1:/home/inf/Bilder/Road/jsons/image0072.json
# 2:/home/inf/Bilder/Road/jsons/image0079.json
# 3:/home/inf/Bilder/Road/jsons/image0124.json
# 4:/home/inf/Bilder/Road/jsons/image0135.json
# 5:/home/inf/Bilder/Road/jsons/image0208.json
# 6:/home/inf/Bilder/Road/jsons/image0140.json
# 7:/home/inf/Bilder/Road/jsons/image0138.json
# 8:/home/inf/Bilder/Road/jsons/image0039.json
# 9:/home/inf/Bilder/Road/jsons/image0154.json
# 10:/home/inf/Bilder/Road/jsons/image0026.json
# 11:/home/inf/Bilder/Road/jsons/image0141.json
# 12:/home/inf/Bilder/Road/jsons/image0220.json
# 13:/home/inf/Bilder/Road/jsons/image0018.json
# 14:/home/inf/Bilder/Road/jsons/image0041.json
# 15:/home/inf/Bilder/Road/jsons/image0175.json
# 16:/home/inf/Bilder/Road/jsons/image0216.json
# 17:/home/inf/Bilder/Road/jsons/image0177.json
# 18:/home/inf/Bilder/Road/jsons/image0096.json
# 19:/home/inf/Bilder/Road/jsons/image0225.json
# 20:/home/inf/Bilder/Road/jsons/image0103.json
# 21:/home/inf/Bilder/Road/jsons/image0028.json
# 22:/home/inf/Bilder/Road/jsons/image0157.json
# 23:/home/inf/Bilder/Road/jsons/image0046.json
# 24:/home/inf/Bilder/Road/jsons/image0169.json
# 25:/home/inf/Bilder/Road/jsons/image0098.json
# 26:/home/inf/Bilder/Road/jsons/image0061.json
# 27:/home/inf/Bilder/Road/jsons/image0195.json
# 28:/home/inf/Bilder/Road/jsons/image0172.json
# 29:/home/inf/Bilder/Road/jsons/image0129.json
# 30:/home/inf/Bilder/Road/jsons/image0145.json
# 31:/home/inf/Bilder/Road/jsons/image0036.json
# 32:/home/inf/Bilder/Road/jsons/image0125.json
# 33:/home/inf/Bilder/Road/jsons/image0095.json
# 34:/home/inf/Bilder/Road/jsons/image0229.json
# 35:/home/inf/Bilder/Road/jsons/image0063.json
# 36:/home/inf/Bilder/Road/jsons/image0207.json
# 37:/home/inf/Bilder/Road/jsons/image0230.json
# 38:/home/inf/Bilder/Road/jsons/image0209.json
# 39:/home/inf/Bilder/Road/jsons/image0123.json
# 40:/home/inf/Bilder/Road/jsons/image0119.json
# 41:/home/inf/Bilder/Road/jsons/image0021.json
# 42:/home/inf/Bilder/Road/jsons/image0127.json
# 43:/home/inf/Bilder/Road/jsons/image0150.json
# 44:/home/inf/Bilder/Road/jsons/image0183.json
# 45:/home/inf/Bilder/Road/jsons/image0014.json
# 155:/home/inf/Bilder/Road/jsons/image0020.json
# 156:/home/inf/Bilder/Road/jsons/image0054.json
# 157:/home/inf/Bilder/Road/jsons/image0044.json
# 158:/home/inf/Bilder/Road/jsons/image0080.json
# 159:/home/inf/Bilder/Road/jsons/image0139.json
# 160:/home/inf/Bilder/Road/jsons/image0062.json
# 161:/home/inf/Bilder/Road/jsons/image0198.json
# 162:/home/inf/Bilder/Road/jsons/image0210.json
# 163:/home/inf/Bilder/Road/jsons/image0051.json
# 164:/home/inf/Bilder/Road/jsons/image0151.json
# 165:/home/inf/Bilder/Road/jsons/image0215.json
# 166:/home/inf/Bilder/Road/jsons/image0040.json
# 167:/home/inf/Bilder/Road/jsons/image0102.json
# 168:/home/inf/Bilder/Road/jsons/image0086.json
# 169:/home/inf/Bilder/Road/jsons/image0015.json
# 170:/home/inf/Bilder/Road/jsons/image0120.json
# 171:/home/inf/Bilder/Road/jsons/image0156.json
# 172:/home/inf/Bilder/Road/jsons/image0184.json
# 173:/home/inf/Bilder/Road/jsons/image0142.json
# 174:/home/inf/Bilder/Road/jsons/image0065.json
# 175:/home/inf/Bilder/Road/jsons/image0199.json
# 176:/home/inf/Bilder/Road/jsons/image0089.json
# 177:/home/inf/Bilder/Road/jsons/image0211.json
# 178:/home/inf/Bilder/Road/jsons/image0045.json
# 179:/home/inf/Bilder/Road/jsons/image0022.json
# 180:/home/inf/Bilder/Road/jsons/image0130.json
# 181:/home/inf/Bilder/Road/jsons/image0048.json
# 182:/home/inf/Bilder/Road/jsons/image0218.json
# 183:/home/inf/Bilder/Road/jsons/image0131.json
# 184:/home/inf/Bilder/Road/jsons/image0027.json
# 185:/home/inf/Bilder/Road/jsons/image0008.json
# 186:/home/inf/Bilder/Road/jsons/image0227.json
# 187:/home/inf/Bilder/Road/jsons/image0164.json
# 188:/home/inf/Bilder/Road/jsons/image0143.json
# 189:/home/inf/Bilder/Road/jsons/image0034.json
# 190:/home/inf/Bilder/Road/jsons/image0118.json
# 191:/home/inf/Bilder/Road/jsons/image0042.json
# 192:/home/inf/Bilder/Road/jsons/image0148.json
# 193:/home/inf/Bilder/Road/jsons/image0188.json
# 194:/home/inf/Bilder/Road/jsons/image0180.json
# 195:/home/inf/Bilder/Road/jsons/image0167.json
# 196:/home/inf/Bilder/Road/jsons/image0007.json
# 197:/home/inf/Bilder/Road/jsons/image0019.json
# 198:/home/inf/Bilder/Road/jsons/image0069.json
# 199:/home/inf/Bilder/Road/jsons/image0074.json
# 200:/home/inf/Bilder/Road/jsons/image0146.json
# 201:/home/inf/Bilder/Road/jsons/image0075.json
# 202:/home/inf/Bilder/Road/jsons/image0060.json
# 203:/home/inf/Bilder/Road/jsons/image0190.json
# 204:/home/inf/Bilder/Road/jsons/image0064.json
# 205:/home/inf/Bilder/Road/jsons/image0053.json
# 206:/home/inf/Bilder/Road/jsons/image0163.json
# 207:/home/inf/Bilder/Road/jsons/image0202.json
# 0:/home/inf/Bilder/Road/jsons/image0144.json
# 1:/home/inf/Bilder/Road/jsons/image0072.json
# 2:/home/inf/Bilder/Road/jsons/image0079.json
# 3:/home/inf/Bilder/Road/jsons/image0124.json
# 4:/home/inf/Bilder/Road/jsons/image0135.json
# 5:/home/inf/Bilder/Road/jsons/image0208.json
# 6:/home/inf/Bilder/Road/jsons/image0140.json
# 7:/home/inf/Bilder/Road/jsons/image0138.json
# 8:/home/inf/Bilder/Road/jsons/image0039.json
# 9:/home/inf/Bilder/Road/jsons/image0154.json
# 10:/home/inf/Bilder/Road/jsons/image0026.json
# 11:/home/inf/Bilder/Road/jsons/image0141.json
# 12:/home/inf/Bilder/Road/jsons/image0220.json
# 13:/home/inf/Bilder/Road/jsons/image0018.json
# 14:/home/inf/Bilder/Road/jsons/image0041.json
# 15:/home/inf/Bilder/Road/jsons/image0175.json
# 16:/home/inf/Bilder/Road/jsons/image0216.json
# 17:/home/inf/Bilder/Road/jsons/image0177.json
# 18:/home/inf/Bilder/Road/jsons/image0096.json
# 19:/home/inf/Bilder/Road/jsons/image0225.json
# 20:/home/inf/Bilder/Road/jsons/image0103.json
# 21:/home/inf/Bilder/Road/jsons/image0028.json
# 22:/home/inf/Bilder/Road/jsons/image0157.json
# 23:/home/inf/Bilder/Road/jsons/image0046.json
# 24:/home/inf/Bilder/Road/jsons/image0169.json
# 25:/home/inf/Bilder/Road/jsons/image0098.json
# 26:/home/inf/Bilder/Road/jsons/image0061.json
# 27:/home/inf/Bilder/Road/jsons/image0195.json
# 28:/home/inf/Bilder/Road/jsons/image0172.json
# 29:/home/inf/Bilder/Road/jsons/image0129.json
# 30:/home/inf/Bilder/Road/jsons/image0145.json
# 31:/home/inf/Bilder/Road/jsons/image0036.json
# 32:/home/inf/Bilder/Road/jsons/image0125.json
# 33:/home/inf/Bilder/Road/jsons/image0095.json
# 34:/home/inf/Bilder/Road/jsons/image0229.json
# 35:/home/inf/Bilder/Road/jsons/image0063.json
# 36:/home/inf/Bilder/Road/jsons/image0207.json
# 37:/home/inf/Bilder/Road/jsons/image0230.json
# 38:/home/inf/Bilder/Road/jsons/image0209.json
# 39:/home/inf/Bilder/Road/jsons/image0123.json
# 40:/home/inf/Bilder/Road/jsons/image0119.json
# 41:/home/inf/Bilder/Road/jsons/image0021.json
# 42:/home/inf/Bilder/Road/jsons/image0127.json
# 43:/home/inf/Bilder/Road/jsons/image0150.json
# 44:/home/inf/Bilder/Road/jsons/image0183.json
# 45:/home/inf/Bilder/Road/jsons/image0014.json
# 46:/home/inf/Bilder/Road/jsons/image0214.json
# 47:/home/inf/Bilder/Road/jsons/image0033.json
# 48:/home/inf/Bilder/Road/jsons/image0009.json
# 49:/home/inf/Bilder/Road/jsons/image0205.json
# 50:/home/inf/Bilder/Road/jsons/image0231.json
# 51:/home/inf/Bilder/Road/jsons/image0078.json
# 52:/home/inf/Bilder/Road/jsons/image0161.json
# 53:/home/inf/Bilder/Road/jsons/image0023.json
# 54:/home/inf/Bilder/Road/jsons/image0176.json
# 55:/home/inf/Bilder/Road/jsons/image0101.json
# 56:/home/inf/Bilder/Road/jsons/image0191.json
# 57:/home/inf/Bilder/Road/jsons/image0109.json
# 58:/home/inf/Bilder/Road/jsons/image0077.json
# 59:/home/inf/Bilder/Road/jsons/image0052.json
# 60:/home/inf/Bilder/Road/jsons/image0043.json
# 61:/home/inf/Bilder/Road/jsons/image0112.json
# 62:/home/inf/Bilder/Road/jsons/image0056.json
# 63:/home/inf/Bilder/Road/jsons/image0122.json
# 64:/home/inf/Bilder/Road/jsons/image0084.json
# 65:/home/inf/Bilder/Road/jsons/image0219.json
# 66:/home/inf/Bilder/Road/jsons/image0181.json
# 67:/home/inf/Bilder/Road/jsons/image0105.json
# 68:/home/inf/Bilder/Road/jsons/image0226.json
# 69:/home/inf/Bilder/Road/jsons/image0168.json
# 70:/home/inf/Bilder/Road/jsons/image0228.json
# 71:/home/inf/Bilder/Road/jsons/image0116.json
# 72:/home/inf/Bilder/Road/jsons/image0031.json
# 73:/home/inf/Bilder/Road/jsons/image0115.json
# 74:/home/inf/Bilder/Road/jsons/image0082.json
# 75:/home/inf/Bilder/Road/jsons/image0149.json
# 76:/home/inf/Bilder/Road/jsons/image0076.json
# 77:/home/inf/Bilder/Road/jsons/image0212.json
# 78:/home/inf/Bilder/Road/jsons/image0090.json
# 79:/home/inf/Bilder/Road/jsons/image0012.json
# 80:/home/inf/Bilder/Road/jsons/image0088.json
# 81:/home/inf/Bilder/Road/jsons/image0182.json
# 82:/home/inf/Bilder/Road/jsons/image0001.json
# 83:/home/inf/Bilder/Road/jsons/image0066.json
# 84:/home/inf/Bilder/Road/jsons/image0201.json
# 85:/home/inf/Bilder/Road/jsons/image0035.json
# 86:/home/inf/Bilder/Road/jsons/image0087.json
# 87:/home/inf/Bilder/Road/jsons/image0194.json
# 88:/home/inf/Bilder/Road/jsons/image0192.json
# 89:/home/inf/Bilder/Road/jsons/image0153.json
# 90:/home/inf/Bilder/Road/jsons/image0178.json
# 91:/home/inf/Bilder/Road/jsons/image0049.json
# 92:/home/inf/Bilder/Road/jsons/image0113.json
# 93:/home/inf/Bilder/Road/jsons/image0170.json
# 94:/home/inf/Bilder/Road/jsons/image0108.json
# 95:/home/inf/Bilder/Road/jsons/image0071.json
# 96:/home/inf/Bilder/Road/jsons/image0081.json
# 97:/home/inf/Bilder/Road/jsons/image0114.json
# 98:/home/inf/Bilder/Road/jsons/image0085.json
# 99:/home/inf/Bilder/Road/jsons/image0193.json
# 100:/home/inf/Bilder/Road/jsons/image0189.json
# 101:/home/inf/Bilder/Road/jsons/image0160.json
# 102:/home/inf/Bilder/Road/jsons/image0171.json
# 103:/home/inf/Bilder/Road/jsons/image0037.json
# 104:/home/inf/Bilder/Road/jsons/image0032.json
# 105:/home/inf/Bilder/Road/jsons/image0133.json
# 106:/home/inf/Bilder/Road/jsons/image0017.json
# 107:/home/inf/Bilder/Road/jsons/image0173.json
# 108:/home/inf/Bilder/Road/jsons/image0217.json
# 109:/home/inf/Bilder/Road/jsons/image0024.json
# 110:/home/inf/Bilder/Road/jsons/image0222.json
# 111:/home/inf/Bilder/Road/jsons/image0117.json
# 112:/home/inf/Bilder/Road/jsons/image0100.json
# 113:/home/inf/Bilder/Road/jsons/image0233.json
# 114:/home/inf/Bilder/Road/jsons/image0070.json
# 115:/home/inf/Bilder/Road/jsons/image0121.json
# 116:/home/inf/Bilder/Road/jsons/image0203.json
# 117:/home/inf/Bilder/Road/jsons/image0093.json
# 118:/home/inf/Bilder/Road/jsons/image0058.json
# 119:/home/inf/Bilder/Road/jsons/image0097.json
# 120:/home/inf/Bilder/Road/jsons/image0057.json
# 121:/home/inf/Bilder/Road/jsons/image0104.json
# 122:/home/inf/Bilder/Road/jsons/image0137.json
# 123:/home/inf/Bilder/Road/jsons/image0091.json
# 124:/home/inf/Bilder/Road/jsons/image0162.json
# 125:/home/inf/Bilder/Road/jsons/image0006.json
# 126:/home/inf/Bilder/Road/jsons/image0047.json
# 127:/home/inf/Bilder/Road/jsons/image0147.json
# 128:/home/inf/Bilder/Road/jsons/image0005.json
# 129:/home/inf/Bilder/Road/jsons/image0165.json
# 130:/home/inf/Bilder/Road/jsons/image0067.json
# 131:/home/inf/Bilder/Road/jsons/image0213.json
# 132:/home/inf/Bilder/Road/jsons/image0166.json
# 133:/home/inf/Bilder/Road/jsons/image0196.json
# 134:/home/inf/Bilder/Road/jsons/image0073.json
# 135:/home/inf/Bilder/Road/jsons/image0111.json
# 136:/home/inf/Bilder/Road/jsons/image0200.json
# 137:/home/inf/Bilder/Road/jsons/image0025.json
# 138:/home/inf/Bilder/Road/jsons/image0197.json
# 139:/home/inf/Bilder/Road/jsons/image0223.json
# 140:/home/inf/Bilder/Road/jsons/image0011.json
# 141:/home/inf/Bilder/Road/jsons/image0174.json
# 142:/home/inf/Bilder/Road/jsons/image0050.json
# 143:/home/inf/Bilder/Road/jsons/image0152.json
# 144:/home/inf/Bilder/Road/jsons/image0179.json
# 145:/home/inf/Bilder/Road/jsons/image0013.json
# 146:/home/inf/Bilder/Road/jsons/image0029.json
# 147:/home/inf/Bilder/Road/jsons/image0003.json
# 148:/home/inf/Bilder/Road/jsons/image0185.json
# 149:/home/inf/Bilder/Road/jsons/image0099.json
# 150:/home/inf/Bilder/Road/jsons/image0030.json
# 151:/home/inf/Bilder/Road/jsons/image0136.json
# 152:/home/inf/Bilder/Road/jsons/image0004.json
# 153:/home/inf/Bilder/Road/jsons/image0106.json
# 154:/home/inf/Bilder/Road/jsons/image0126.json
# 155:/home/inf/Bilder/Road/jsons/image0020.json
# 156:/home/inf/Bilder/Road/jsons/image0054.json
# 157:/home/inf/Bilder/Road/jsons/image0044.json
# 158:/home/inf/Bilder/Road/jsons/image0080.json
# 159:/home/inf/Bilder/Road/jsons/image0139.json
# 160:/home/inf/Bilder/Road/jsons/image0062.json
# 161:/home/inf/Bilder/Road/jsons/image0198.json
# 162:/home/inf/Bilder/Road/jsons/image0210.json
# 163:/home/inf/Bilder/Road/jsons/image0051.json
# 164:/home/inf/Bilder/Road/jsons/image0151.json
# 165:/home/inf/Bilder/Road/jsons/image0215.json
# 166:/home/inf/Bilder/Road/jsons/image0040.json
# 167:/home/inf/Bilder/Road/jsons/image0102.json
# 168:/home/inf/Bilder/Road/jsons/image0086.json
# 169:/home/inf/Bilder/Road/jsons/image0015.json
# 170:/home/inf/Bilder/Road/jsons/image0120.json
# 171:/home/inf/Bilder/Road/jsons/image0156.json
# 172:/home/inf/Bilder/Road/jsons/image0184.json
# 173:/home/inf/Bilder/Road/jsons/image0142.json
# 174:/home/inf/Bilder/Road/jsons/image0065.json
# 175:/home/inf/Bilder/Road/jsons/image0199.json
# 176:/home/inf/Bilder/Road/jsons/image0089.json
# 177:/home/inf/Bilder/Road/jsons/image0211.json
# 178:/home/inf/Bilder/Road/jsons/image0045.json
# 179:/home/inf/Bilder/Road/jsons/image0022.json
# 180:/home/inf/Bilder/Road/jsons/image0130.json
# 181:/home/inf/Bilder/Road/jsons/image0048.json
# 182:/home/inf/Bilder/Road/jsons/image0218.json
# 183:/home/inf/Bilder/Road/jsons/image0131.json
# 184:/home/inf/Bilder/Road/jsons/image0027.json
# 185:/home/inf/Bilder/Road/jsons/image0008.json
# 186:/home/inf/Bilder/Road/jsons/image0227.json
# 187:/home/inf/Bilder/Road/jsons/image0164.json
# 188:/home/inf/Bilder/Road/jsons/image0143.json
# 189:/home/inf/Bilder/Road/jsons/image0034.json
# 190:/home/inf/Bilder/Road/jsons/image0118.json
# 191:/home/inf/Bilder/Road/jsons/image0042.json
# 192:/home/inf/Bilder/Road/jsons/image0148.json
# 193:/home/inf/Bilder/Road/jsons/image0188.json
# 194:/home/inf/Bilder/Road/jsons/image0180.json
# 195:/home/inf/Bilder/Road/jsons/image0167.json
# 196:/home/inf/Bilder/Road/jsons/image0007.json
# 197:/home/inf/Bilder/Road/jsons/image0019.json
# 198:/home/inf/Bilder/Road/jsons/image0069.json
# 199:/home/inf/Bilder/Road/jsons/image0074.json
# 200:/home/inf/Bilder/Road/jsons/image0146.json
# 201:/home/inf/Bilder/Road/jsons/image0075.json
# 202:/home/inf/Bilder/Road/jsons/image0060.json
# 203:/home/inf/Bilder/Road/jsons/image0190.json
# 204:/home/inf/Bilder/Road/jsons/image0064.json
# 205:/home/inf/Bilder/Road/jsons/image0053.json
# 206:/home/inf/Bilder/Road/jsons/image0163.json
# 207:/home/inf/Bilder/Road/jsons/image0202.json

# %%
# start 08.29 voraussichlich ende: 12.29 haelfte

# %%
createMasks(fullpathjsonsvalid, fullpathimagesvalid, fullpathmasksvalid)
createMasksAugmented("a4", fullpathjsonsvalid, fullpathimagesvalid, fullpathmasksvalid)
# Out:
# 0:/home/inf/Bilder/Road/jsons_valid/image0016.json
# 1:/home/inf/Bilder/Road/jsons_valid/image0002.json
# 2:/home/inf/Bilder/Road/jsons_valid/image0186.json
# 3:/home/inf/Bilder/Road/jsons_valid/image0038.json
# 4:/home/inf/Bilder/Road/jsons_valid/image0224.json
# 5:/home/inf/Bilder/Road/jsons_valid/image0107.json
# 6:/home/inf/Bilder/Road/jsons_valid/image0204.json
# 7:/home/inf/Bilder/Road/jsons_valid/image0132.json
# 8:/home/inf/Bilder/Road/jsons_valid/image0221.json
# 9:/home/inf/Bilder/Road/jsons_valid/image0206.json
# 10:/home/inf/Bilder/Road/jsons_valid/image0068.json
# 11:/home/inf/Bilder/Road/jsons_valid/image0059.json
# 12:/home/inf/Bilder/Road/jsons_valid/image0110.json
# 13:/home/inf/Bilder/Road/jsons_valid/image0134.json
# 14:/home/inf/Bilder/Road/jsons_valid/image0232.json
# 15:/home/inf/Bilder/Road/jsons_valid/image0083.json
# 16:/home/inf/Bilder/Road/jsons_valid/image0158.json
# 17:/home/inf/Bilder/Road/jsons_valid/image0092.json
# 18:/home/inf/Bilder/Road/jsons_valid/image0155.json
# 19:/home/inf/Bilder/Road/jsons_valid/image0187.json
# 0:/home/inf/Bilder/Road/jsons_valid/image0016.json
# 1:/home/inf/Bilder/Road/jsons_valid/image0002.json
# 2:/home/inf/Bilder/Road/jsons_valid/image0186.json
# 3:/home/inf/Bilder/Road/jsons_valid/image0038.json
# 4:/home/inf/Bilder/Road/jsons_valid/image0224.json
# 5:/home/inf/Bilder/Road/jsons_valid/image0107.json
# 6:/home/inf/Bilder/Road/jsons_valid/image0204.json
# 7:/home/inf/Bilder/Road/jsons_valid/image0132.json
# 8:/home/inf/Bilder/Road/jsons_valid/image0221.json
# 9:/home/inf/Bilder/Road/jsons_valid/image0206.json
# 10:/home/inf/Bilder/Road/jsons_valid/image0068.json
# 11:/home/inf/Bilder/Road/jsons_valid/image0059.json
# 12:/home/inf/Bilder/Road/jsons_valid/image0110.json
# 13:/home/inf/Bilder/Road/jsons_valid/image0134.json
# 14:/home/inf/Bilder/Road/jsons_valid/image0232.json
# 15:/home/inf/Bilder/Road/jsons_valid/image0083.json
# 16:/home/inf/Bilder/Road/jsons_valid/image0158.json
# 17:/home/inf/Bilder/Road/jsons_valid/image0092.json
# 18:/home/inf/Bilder/Road/jsons_valid/image0155.json
# 19:/home/inf/Bilder/Road/jsons_valid/image0187.json

# %%
def makemask(mask):
    assert(dim[0] == mask.shape[0])
    assert(dim[1] == mask.shape[1])
    ret_mask = np.zeros((dim[0], dim[1], 3), 'uint8')
    for i in range(dim[0]):
        for j in range(dim[1]):
                assert(mask[i,j] < len(colors))
                ret_mask[i,j,0] = colors[mask[i,j]][0]
                ret_mask[i,j,1] = colors[mask[i,j]][1]
                ret_mask[i,j,2] = colors[mask[i,j]][2]
    return ret_mask

# %%
createMasksAugmented("a5",fullpathjsonstest, fullpathimagestest, fullpathmaskstest)
# Out:
# 0:/home/inf/Bilder/Road/jsons_test/image0055.json
# 1:/home/inf/Bilder/Road/jsons_test/image0159.json
# 2:/home/inf/Bilder/Road/jsons_test/image0094.json
# 3:/home/inf/Bilder/Road/jsons_test/image0128.json
# 4:/home/inf/Bilder/Road/jsons_test/image0010.json

# %%
print(dim)
# Out:
# (128, 128)

# %%
imagetestlist = []

imagetestnames = os.listdir(fullpathimagesvalid)
imagetestnames.sort()

masktestlist = []

masktestnames = os.listdir(fullpathmasksvalid)
masktestnames.sort()

for imagename in imagetestnames:
    if imagename.endswith(".png"):
        imagetestlist.append(cv2.imread(os.path.join(fullpathimagesvalid,imagename),cv2.IMREAD_COLOR ))

for maskname in masktestnames:
    if maskname.endswith(".png"):
        masktestlist.append(makemask(cv2.imread(os.path.join(fullpathmasksvalid,maskname),cv2.IMREAD_UNCHANGED )))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-05bfea40dfce> in <module>
#      15 for maskname in masktestnames:
#      16     if maskname.endswith(".png"):
# ---> 17         masktestlist.append(makemask(cv2.imread(os.path.join(fullpathmasksvalid,maskname),cv2.IMREAD_UNCHANGED )))
#      18
#
# <ipython-input-7-468ced26c5ea> in makemask(mask)
#       9                 ret_mask[i,j,0] = colors[mask[i,j]][0]
#      10                 ret_mask[i,j,1] = colors[mask[i,j]][1]
# ---> 11                 ret_mask[i,j,2] = colors[mask[i,j]][2]
#      12                 #print(colors[mask[i,j]])
#      13                 #print(mask[i,j])
#
# KeyboardInterrupt:

# %%
j = 10
plt.imshow(imagetestlist[j])

# %%
plt.imshow(masktestlist[j])

# %%
weighted = np.zeros((dim[0], dim[1], 3), 'uint8')
cv2.addWeighted(imagetestlist[j], 0.5, masktestlist[j], 0.5, 0, weighted)
plt.imshow(weighted)

# %%
assert(len(imagetestlist) == len(masktestlist))

for i in range(len(imagetestlist)):
    weighted = np.zeros((dim[0], dim[1], 3), 'uint8')
    cv2.addWeighted(imagetestlist[i], 0.5, masktestlist[i], 0.5, 0, weighted)
    #plt.imshow(weighted)
    cv2.imwrite(os.path.join(path,"comparison","image{}-orig.png".format(i)),weighted)

# %%
def checkimages(fullpathimages, fullpathmasks):
    imagenames = []
    masknames = []
    imagenames = os.listdir(fullpathimages)
    imagenames.sort()

    masknames = os.listdir(fullpathmasks)
    masknames.sort()

    assert (len(imagenames) == len(masknames))

    for j in range(len(imagenames)):
        assert(imagenames[j] == masknames[j])

    for j in range(len(imagenames)):
        print(imagenames[j])
        
        origname =os.path.join(fullpathimages,imagenames[j])
        maskname = os.path.join(fullpathmasks, masknames[j])
        weighted = np.zeros((dim[0], dim[1], 3), 'uint8')
        origimg = cv2.imread(origname,cv2.IMREAD_COLOR )
        maskimg =cv2.imread(maskname,cv2.IMREAD_UNCHANGED )
        

        if origimg.shape[0] != dim[0] or origimg.shape[1] != dim[1]:
            print("fail opening orig with {}".format(origname))
            continue
        if maskimg.shape[0] != dim[0] or maskimg.shape[1] != dim[1]:
            print("fail opening mask with {}".format(maskname))
            continue           

        cv2.addWeighted(origimg, 0.5, makemask(maskimg), 0.5, 0, weighted)
        cv2.imwrite(os.path.join(path,"comparison", imagenames[j]),weighted)

# %%
print(fullpathimages)
print(fullpathmasks)
checkimages(fullpathimages, fullpathmasks)
checkimages(fullpathimagesvalid, fullpathmasksvalid)
checkimages(fullpathimagestest, fullpathmaskstest)
# Out:
# /home/inf/Bilder/Road/images
# /home/inf/Bilder/Road/masks
# image0001a1.png
# image0001a2.png
# image0001a3.png
